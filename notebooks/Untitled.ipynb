# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import json

# %%
df = gpd.read_file('digitalglobe_crowdsourcing_hurricane_harvey_20170915.geojson')

# %%
df1 = df.ix[0]
series = gpd.GeoSeries(df1)
deg2km = 111
series.length * deg2km
ax = series.plot()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                   id  tag_id                       label  tagger_id  type_id  \
# 0          214149-59      59  Flooded / Damaged Building      30425      226
# 1          214149-72      72  Flooded / Damaged Building    6294177      226
# 2          214149-76      76  Flooded / Damaged Building    6294177      226
# 3         214149-108     108  Flooded / Damaged Building    6294177      226
# 4         214149-111     111  Flooded / Damaged Building    6294177      226
# 5         214149-113     113  Flooded / Damaged Building    6294177      226
# 6         214149-115     115  Flooded / Damaged Building    6294177      226
# 7         214149-124     124  Flooded / Damaged Building    6294177      226
# 8         214149-134     134  Flooded / Damaged Building    6294177      226
# 9         214149-141     141  Flooded / Damaged Building    6294177      226
# 10        214149-144     144  Flooded / Damaged Building    6294177      226
# ...
